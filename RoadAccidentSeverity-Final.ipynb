# %% [markdown]
# # checking the accident severity based on different conditions

# %% [markdown]
# #### Key Features:
# #### Driver Attributes: Age band, Sex, Educational Level, Driving Experience
# #### Road and Environmental Factors: Road Surface Type, Light Conditions, Weather Conditions, Types of Junction
# #### Accident Details: Type of Collision, Vehicle Movement, Pedestrian Movement, Cause of Accident
# #### Dependent Variable: Accident Severity: An integer representing the severity of an accident 0:serious injured,1:Slight injured.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
RAS=pd.read_csv(r"D:\Dataset\RoadAccident.csv")
RAS
# Out:
#       Age_band_of_driver Sex_of_driver   Educational_level  \
# 0                  18-30          Male   Above high school
# 1                  31-50          Male  Junior high school
# 2                  18-30          Male  Junior high school
# 3                  18-30          Male  Junior high school
# 4                  18-30          Male  Junior high school
# ...                  ...           ...                 ...
# 12153              31-50          Male             Unknown
# 12154            Unknown          Male   Elementary school
# 12155            Over 51          Male  Junior high school
# 12156              18-30        Female  Junior high school
# 12157              18-30          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience  \
# 0                    Employee              1-2yr
# 1                    Employee         Above 10yr
# 2                    Employee              1-2yr
# 3                    Employee             5-10yr
# 4                    Employee              2-5yr
# ...                       ...                ...
# 12153                Employee              2-5yr
# 12154                Employee             5-10yr
# 12155                Employee             5-10yr
# 12156                Employee         Above 10yr
# 12157                Employee             5-10yr
#
#                                        Lanes_or_Medians Types_of_Junction  \
# 0                                               Unknown       No junction
# 1                                     Undivided Two way       No junction
# 2                                                 other       No junction
# 3                                                 other           Y Shape
# 4                                                 other           Y Shape
# ...                                                 ...               ...
# 12153                                 Undivided Two way       No junction
# 12154  Two-way (divided with broken lines road marking)       No junction
# 12155  Two-way (divided with broken lines road marking)       No junction
# 12156                                 Undivided Two way       No junction
# 12157                                 Undivided Two way           O Shape
#
#       Road_surface_type       Light_conditions Weather_conditions  \
# 0         Asphalt roads               Daylight             Normal
# 1         Asphalt roads               Daylight             Normal
# 2         Asphalt roads               Daylight             Normal
# 3           Earth roads  Darkness - lights lit             Normal
# 4         Asphalt roads  Darkness - lights lit             Normal
# ...                 ...                    ...                ...
# 12153     Asphalt roads               Daylight             Normal
# 12154     Asphalt roads               Daylight             Normal
# 12155     Asphalt roads               Daylight             Normal
# 12156     Asphalt roads  Darkness - lights lit             Normal
# 12157     Asphalt roads  Darkness - lights lit             Normal
#
#                              Type_of_collision Vehicle_movement  \
# 0      Collision with roadside-parked vehicles   Going straight
# 1               Vehicle with vehicle collision   Going straight
# 2              Collision with roadside objects   Going straight
# 3               Vehicle with vehicle collision   Going straight
# 4               Vehicle with vehicle collision   Going straight
# ...                                        ...              ...
# 12153           Vehicle with vehicle collision   Going straight
# 12154           Vehicle with vehicle collision            Other
# 12155           Vehicle with vehicle collision            Other
# 12156           Vehicle with vehicle collision            Other
# 12157           Vehicle with vehicle collision         Stopping
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12153                                   Not a Pedestrian
# 12154                                   Not a Pedestrian
# 12155                                   Not a Pedestrian
# 12156                                   Not a Pedestrian
# 12157  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident  Accident_severity
# 0                           Moving Backward                  1
# 1                                Overtaking                  1
# 2                 Changing lane to the left                  0
# 3                Changing lane to the right                  1
# 4                                Overtaking                  1
# ...                                     ...                ...
# 12153                         No distancing                  1
# 12154                         No distancing                  1
# 12155            Changing lane to the right                  0
# 12156  Driving under the influence of drugs                  1
# 12157            Changing lane to the right                  1
#
# [12158 rows x 15 columns]

# %% [markdown]
# #### Data Preprocessing

# %%
RAS.head(2)
# Out:
#   Age_band_of_driver Sex_of_driver   Educational_level  \
# 0              18-30          Male   Above high school
# 1              31-50          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience   Lanes_or_Medians  \
# 0                Employee              1-2yr            Unknown
# 1                Employee         Above 10yr  Undivided Two way
#
#   Types_of_Junction Road_surface_type Light_conditions Weather_conditions  \
# 0       No junction     Asphalt roads         Daylight             Normal
# 1       No junction     Asphalt roads         Daylight             Normal
#
#                          Type_of_collision Vehicle_movement  \
# 0  Collision with roadside-parked vehicles   Going straight
# 1           Vehicle with vehicle collision   Going straight
#
#   Pedestrian_movement Cause_of_accident  Accident_severity
# 0    Not a Pedestrian   Moving Backward                  1
# 1    Not a Pedestrian        Overtaking                  1

# %%
RAS.tail()
# Out:
#       Age_band_of_driver Sex_of_driver   Educational_level  \
# 12153              31-50          Male             Unknown
# 12154            Unknown          Male   Elementary school
# 12155            Over 51          Male  Junior high school
# 12156              18-30        Female  Junior high school
# 12157              18-30          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience  \
# 12153                Employee              2-5yr
# 12154                Employee             5-10yr
# 12155                Employee             5-10yr
# 12156                Employee         Above 10yr
# 12157                Employee             5-10yr
#
#                                        Lanes_or_Medians Types_of_Junction  \
# 12153                                 Undivided Two way       No junction
# 12154  Two-way (divided with broken lines road marking)       No junction
# 12155  Two-way (divided with broken lines road marking)       No junction
# 12156                                 Undivided Two way       No junction
# 12157                                 Undivided Two way           O Shape
#
#       Road_surface_type       Light_conditions Weather_conditions  \
# 12153     Asphalt roads               Daylight             Normal
# 12154     Asphalt roads               Daylight             Normal
# 12155     Asphalt roads               Daylight             Normal
# 12156     Asphalt roads  Darkness - lights lit             Normal
# 12157     Asphalt roads  Darkness - lights lit             Normal
#
#                     Type_of_collision Vehicle_movement  \
# 12153  Vehicle with vehicle collision   Going straight
# 12154  Vehicle with vehicle collision            Other
# 12155  Vehicle with vehicle collision            Other
# 12156  Vehicle with vehicle collision            Other
# 12157  Vehicle with vehicle collision         Stopping
#
#                                      Pedestrian_movement  \
# 12153                                   Not a Pedestrian
# 12154                                   Not a Pedestrian
# 12155                                   Not a Pedestrian
# 12156                                   Not a Pedestrian
# 12157  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident  Accident_severity
# 12153                         No distancing                  1
# 12154                         No distancing                  1
# 12155            Changing lane to the right                  0
# 12156  Driving under the influence of drugs                  1
# 12157            Changing lane to the right                  1

# %%
RAS.columns
# Out:
# Index(['Age_band_of_driver', 'Sex_of_driver', 'Educational_level',
#        'Vehicle_driver_relation', 'Driving_experience', 'Lanes_or_Medians',
#        'Types_of_Junction', 'Road_surface_type', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision', 'Vehicle_movement',
#        'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
RAS.shape
# Out:
# (12158, 15)

# %%
RAS.describe(include="all")
# Out:
#        Age_band_of_driver Sex_of_driver   Educational_level  \
# count               12158         12158               12158
# unique                  5             3                   7
# top                 18-30          Male  Junior high school
# freq                 4209         11285                7522
# mean                  NaN           NaN                 NaN
# std                   NaN           NaN                 NaN
# min                   NaN           NaN                 NaN
# 25%                   NaN           NaN                 NaN
# 50%                   NaN           NaN                 NaN
# 75%                   NaN           NaN                 NaN
# max                   NaN           NaN                 NaN
#
#        Vehicle_driver_relation Driving_experience  \
# count                    12158              12158
# unique                       4                  8
# top                   Employee             5-10yr
# freq                      9513               3322
# mean                       NaN                NaN
# std                        NaN                NaN
# min                        NaN                NaN
# 25%                        NaN                NaN
# 50%                        NaN                NaN
# 75%                        NaN                NaN
# max                        NaN                NaN
#
#                                         Lanes_or_Medians Types_of_Junction  \
# count                                              12158             12158
# unique                                                 7                 8
# top     Two-way (divided with broken lines road marking)           Y Shape
# freq                                                4362              4490
# mean                                                 NaN               NaN
# std                                                  NaN               NaN
# min                                                  NaN               NaN
# 25%                                                  NaN               NaN
# 50%                                                  NaN               NaN
# 75%                                                  NaN               NaN
# max                                                  NaN               NaN
#
#        Road_surface_type Light_conditions Weather_conditions  \
# count              12158            12158              12158
# unique                 6                4                  9
# top        Asphalt roads         Daylight             Normal
# freq               11148             8711               9928
# mean                 NaN              NaN                NaN
# std                  NaN              NaN                NaN
# min                  NaN              NaN                NaN
# 25%                  NaN              NaN                NaN
# 50%                  NaN              NaN                NaN
# 75%                  NaN              NaN                NaN
# max                  NaN              NaN                NaN
#
#                      Type_of_collision Vehicle_movement Pedestrian_movement  \
# count                            12158            12158               12158
# unique                              10               13                   9
# top     Vehicle with vehicle collision   Going straight    Not a Pedestrian
# freq                              8670             8059               11248
# mean                               NaN              NaN                 NaN
# std                                NaN              NaN                 NaN
# min                                NaN              NaN                 NaN
# 25%                                NaN              NaN                 NaN
# 50%                                NaN              NaN                 NaN
# 75%                                NaN              NaN                 NaN
# max                                NaN              NaN                 NaN
#
#        Cause_of_accident  Accident_severity
# count              12158       12158.000000
# unique                20                NaN
# top        No distancing                NaN
# freq                2243                NaN
# mean                 NaN           0.856638
# std                  NaN           0.350456
# min                  NaN           0.000000
# 25%                  NaN           1.000000
# 50%                  NaN           1.000000
# 75%                  NaN           1.000000
# max                  NaN           1.000000

# %%
RAS.isnull().sum()
# Out:
# Age_band_of_driver         0
# Sex_of_driver              0
# Educational_level          0
# Vehicle_driver_relation    0
# Driving_experience         0
# Lanes_or_Medians           0
# Types_of_Junction          0
# Road_surface_type          0
# Light_conditions           0
# Weather_conditions         0
# Type_of_collision          0
# Vehicle_movement           0
# Pedestrian_movement        0
# Cause_of_accident          0
# Accident_severity          0
# dtype: int64

# %%
RAS.dtypes
# Out:
# Age_band_of_driver         object
# Sex_of_driver              object
# Educational_level          object
# Vehicle_driver_relation    object
# Driving_experience         object
# Lanes_or_Medians           object
# Types_of_Junction          object
# Road_surface_type          object
# Light_conditions           object
# Weather_conditions         object
# Type_of_collision          object
# Vehicle_movement           object
# Pedestrian_movement        object
# Cause_of_accident          object
# Accident_severity           int64
# dtype: object

# %%
RAS.Age_band_of_driver.value_counts()
# Out:
# Age_band_of_driver
# 18-30       4209
# 31-50       4033
# Over 51     1561
# Unknown     1542
# Under 18     813
# Name: count, dtype: int64

# %%
RAS.Sex_of_driver.value_counts()
# Out:
# Sex_of_driver
# Male       11285
# Female       696
# Unknown      177
# Name: count, dtype: int64

# %%
RAS.Educational_level.value_counts()
# Out:
# Educational_level
# Junior high school    7522
# Elementary school     2139
# High school           1095
# Unknown                827
# Above high school      357
# Writing & reading      173
# Illiterate              45
# Name: count, dtype: int64

# %%
RAS.Vehicle_driver_relation.value_counts()
# Out:
# Vehicle_driver_relation
# Employee    9513
# Owner       1939
# Unknown      584
# Other        122
# Name: count, dtype: int64

# %%
RAS.Driving_experience.value_counts()
# Out:
# Driving_experience
# 5-10yr        3322
# 2-5yr         2567
# Above 10yr    2233
# 1-2yr         1735
# Below 1yr     1335
# Unknown        816
# No Licence     118
# unknown         32
# Name: count, dtype: int64

# %%
RAS.Lanes_or_Medians.value_counts()
# Out:
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4362
# Undivided Two way                                   3734
# other                                               1638
# Double carriageway (median)                         1013
# One way                                              833
# Unknown                                              437
# Two-way (divided with solid lines road marking)      141
# Name: count, dtype: int64

# %%
RAS.Types_of_Junction.value_counts()
# Out:
# Types_of_Junction
# Y Shape        4490
# No junction    3766
# Crossing       2165
# Unknown        1059
# Other           443
# O Shape         163
# T Shape          60
# X Shape          12
# Name: count, dtype: int64

# %%
RAS.Road_surface_type.value_counts()
# Out:
# Road_surface_type
# Asphalt roads                       11148
# Earth roads                           351
# Gravel roads                          242
# Unknown                               171
# Other                                 166
# Asphalt roads with some distress       80
# Name: count, dtype: int64

# %%
RAS.Light_conditions.value_counts()
# Out:
# Light_conditions
# Daylight                   8711
# Darkness - lights lit      3220
# Darkness - no lighting      187
# Darkness - lights unlit      40
# Name: count, dtype: int64

# %%
RAS.Weather_conditions.value_counts()
# Out:
# Weather_conditions
# Normal               9928
# Raining              1308
# Other                 296
# Unknown               292
# Cloudy                125
# Windy                  98
# Snow                   61
# Raining and Windy      40
# Fog or mist            10
# Name: count, dtype: int64

# %%
RAS.Type_of_collision.value_counts()
# Out:
# Type_of_collision
# Vehicle with vehicle collision             8670
# Collision with roadside objects            1762
# Collision with pedestrians                  874
# Rollover                                    393
# Collision with animals                      169
# Unknown                                     167
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# With Train                                    9
# Name: count, dtype: int64

# %%
RAS.Vehicle_movement.value_counts()
# Out:
# Vehicle_movement
# Going straight         8059
# Moving Backward         973
# Other                   927
# Reversing               556
# Turnover                482
# Unknown                 389
# Getting off             334
# Entering a junction     189
# Overtaking               91
# Stopping                 60
# U-Turn                   50
# Waiting to go            38
# Parked                   10
# Name: count, dtype: int64

# %%
RAS.Pedestrian_movement.value_counts()
# Out:
# Pedestrian_movement
# Not a Pedestrian                                                                                                                         11248
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle                                                              330
# Unknown or other                                                                                                                           286
# Crossing from driver's nearside                                                                                                            139
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle                                                               71
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)                                                              46
# Walking along in carriageway, back to traffic                                                                                               18
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle       13
# Walking along in carriageway, facing traffic                                                                                                 7
# Name: count, dtype: int64

# %%
RAS.Cause_of_accident.value_counts()
# Out:
# Cause_of_accident
# No distancing                           2243
# Changing lane to the right              1785
# Changing lane to the left               1457
# Driving carelessly                      1380
# No priority to vehicle                  1194
# Moving Backward                         1111
# No priority to pedestrian                716
# Other                                    449
# Overtaking                               426
# Driving under the influence of drugs     335
# Driving to the left                      280
# Getting off the vehicle improperly       194
# Driving at high speed                    172
# Overturning                              147
# Turnover                                  76
# Overspeed                                 60
# Overloading                               57
# Drunk driving                             27
# Unknown                                   25
# Improper parking                          24
# Name: count, dtype: int64

# %% [markdown]
# #### Slight Injury 10415 ,Serious Injury 1743

# %%
RAS.Accident_severity.value_counts()
# Out:
# Accident_severity
# 1    10415
# 0     1743
# Name: count, dtype: int64

# %% [markdown]
# #### Mostly data present in object data types before EDA we need to change the dtype of data.

# %%
c_columns=['Age_band_of_driver', 'Sex_of_driver', 'Educational_level',
       'Vehicle_driver_relation', 'Driving_experience', 'Lanes_or_Medians',
       'Types_of_Junction', 'Road_surface_type', 'Light_conditions',
       'Weather_conditions', 'Type_of_collision', 'Vehicle_movement',
       'Pedestrian_movement', 'Cause_of_accident']
for i in c_columns:
    RAS[i] = le.fit_transform(RAS[i])
RAS
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       0              1                  0
# 1                       1              1                  4
# 2                       0              1                  4
# 3                       0              1                  4
# 4                       0              1                  4
# ...                   ...            ...                ...
# 12153                   1              1                  5
# 12154                   4              1                  1
# 12155                   2              1                  4
# 12156                   0              0                  4
# 12157                   0              1                  4
#
#        Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                            0                   0                 5
# 1                            0                   3                 4
# 2                            0                   0                 6
# 3                            0                   2                 6
# 4                            0                   1                 6
# ...                        ...                 ...               ...
# 12153                        0                   1                 4
# 12154                        0                   2                 2
# 12155                        0                   2                 2
# 12156                        0                   3                 4
# 12157                        0                   2                 4
#
#        Types_of_Junction  Road_surface_type  Light_conditions  \
# 0                      1                  0                 3
# 1                      1                  0                 3
# 2                      1                  0                 3
# 3                      7                  2                 0
# 4                      7                  0                 0
# ...                  ...                ...               ...
# 12153                  1                  0                 3
# 12154                  1                  0                 3
# 12155                  1                  0                 3
# 12156                  1                  0                 0
# 12157                  2                  0                 0
#
#        Weather_conditions  Type_of_collision  Vehicle_movement  \
# 0                       2                  3                 2
# 1                       2                  8                 2
# 2                       2                  2                 2
# 3                       2                  8                 2
# 4                       2                  8                 2
# ...                   ...                ...               ...
# 12153                   2                  8                 2
# 12154                   2                  8                 4
# 12155                   2                  8                 4
# 12156                   2                  8                 4
# 12157                   2                  8                 8
#
#        Pedestrian_movement  Cause_of_accident  Accident_severity
# 0                        5                  9                  1
# 1                        5                 16                  1
# 2                        5                  0                  0
# 3                        5                  1                  1
# 4                        5                 16                  1
# ...                    ...                ...                ...
# 12153                    5                 10                  1
# 12154                    5                 10                  1
# 12155                    5                  1                  0
# 12156                    5                  5                  1
# 12157                    1                  1                  1
#
# [12158 rows x 15 columns]

# %%
RAS.Accident_severity.value_counts()
# Out:
# Accident_severity
# 1    10415
# 0     1743
# Name: count, dtype: int64

# %% [markdown]
# #### checking the duplicates

# %%
RAS.shape
# Out:
# (12158, 15)

# %%
RAS.drop_duplicates(inplace=True)

# %%
RAS.shape
# Out:
# (11768, 15)

# %% [markdown]
# #### Data Has Duplicate values

# %% [markdown]
# # EDA

# %%
d1=RAS.corr()
d1
# Out:
#                          Age_band_of_driver  Sex_of_driver  Educational_level  \
# Age_band_of_driver                 1.000000      -0.352353           0.018764
# Sex_of_driver                     -0.352353       1.000000           0.005050
# Educational_level                  0.018764       0.005050           1.000000
# Vehicle_driver_relation           -0.010067       0.010250           0.109399
# Driving_experience                -0.014281       0.010598           0.180820
# Lanes_or_Medians                   0.004648      -0.011151           0.003495
# Types_of_Junction                 -0.021598       0.005597           0.011768
# Road_surface_type                 -0.010921      -0.001435           0.011468
# Light_conditions                  -0.003993       0.036216          -0.004729
# Weather_conditions                 0.021549      -0.005968           0.000729
# Type_of_collision                  0.004400      -0.014070          -0.012698
# Vehicle_movement                  -0.009726      -0.001139           0.012829
# Pedestrian_movement                0.002651       0.005750          -0.001290
# Cause_of_accident                 -0.005595       0.001455           0.002445
# Accident_severity                  0.006573       0.009192          -0.001867
#
#                          Vehicle_driver_relation  Driving_experience  \
# Age_band_of_driver                     -0.010067           -0.014281
# Sex_of_driver                           0.010250            0.010598
# Educational_level                       0.109399            0.180820
# Vehicle_driver_relation                 1.000000            0.305722
# Driving_experience                      0.305722            1.000000
# Lanes_or_Medians                        0.025236            0.003453
# Types_of_Junction                      -0.004682            0.003944
# Road_surface_type                      -0.003109            0.011737
# Light_conditions                        0.009298           -0.009567
# Weather_conditions                     -0.023416           -0.004904
# Type_of_collision                       0.007041            0.017453
# Vehicle_movement                       -0.007610            0.002021
# Pedestrian_movement                     0.013438           -0.015941
# Cause_of_accident                      -0.008774           -0.004232
# Accident_severity                       0.000041           -0.009876
#
#                          Lanes_or_Medians  Types_of_Junction  \
# Age_band_of_driver               0.004648          -0.021598
# Sex_of_driver                   -0.011151           0.005597
# Educational_level                0.003495           0.011768
# Vehicle_driver_relation          0.025236          -0.004682
# Driving_experience               0.003453           0.003944
# Lanes_or_Medians                 1.000000          -0.001786
# Types_of_Junction               -0.001786           1.000000
# Road_surface_type               -0.022559           0.000191
# Light_conditions                 0.007833           0.031809
# Weather_conditions               0.005453           0.004526
# Type_of_collision                0.003747           0.004512
# Vehicle_movement                -0.001067          -0.005458
# Pedestrian_movement              0.003130          -0.010285
# Cause_of_accident                0.020810          -0.003684
# Accident_severity               -0.001877          -0.008815
#
#                          Road_surface_type  Light_conditions  \
# Age_band_of_driver               -0.010921         -0.003993
# Sex_of_driver                    -0.001435          0.036216
# Educational_level                 0.011468         -0.004729
# Vehicle_driver_relation          -0.003109          0.009298
# Driving_experience                0.011737         -0.009567
# Lanes_or_Medians                 -0.022559          0.007833
# Types_of_Junction                 0.000191          0.031809
# Road_surface_type                 1.000000         -0.006276
# Light_conditions                 -0.006276          1.000000
# Weather_conditions               -0.003001         -0.065669
# Type_of_collision                -0.007106          0.012082
# Vehicle_movement                 -0.007641          0.025523
# Pedestrian_movement              -0.006213          0.010653
# Cause_of_accident                -0.022179          0.004206
# Accident_severity                -0.003279          0.001503
#
#                          Weather_conditions  Type_of_collision  \
# Age_band_of_driver                 0.021549           0.004400
# Sex_of_driver                     -0.005968          -0.014070
# Educational_level                  0.000729          -0.012698
# Vehicle_driver_relation           -0.023416           0.007041
# Driving_experience                -0.004904           0.017453
# Lanes_or_Medians                   0.005453           0.003747
# Types_of_Junction                  0.004526           0.004512
# Road_surface_type                 -0.003001          -0.007106
# Light_conditions                  -0.065669           0.012082
# Weather_conditions                 1.000000          -0.008243
# Type_of_collision                 -0.008243           1.000000
# Vehicle_movement                   0.003267           0.011909
# Pedestrian_movement                0.020340          -0.011049
# Cause_of_accident                  0.000153           0.013962
# Accident_severity                  0.008444           0.014593
#
#                          Vehicle_movement  Pedestrian_movement  \
# Age_band_of_driver              -0.009726             0.002651
# Sex_of_driver                   -0.001139             0.005750
# Educational_level                0.012829            -0.001290
# Vehicle_driver_relation         -0.007610             0.013438
# Driving_experience               0.002021            -0.015941
# Lanes_or_Medians                -0.001067             0.003130
# Types_of_Junction               -0.005458            -0.010285
# Road_surface_type               -0.007641            -0.006213
# Light_conditions                 0.025523             0.010653
# Weather_conditions               0.003267             0.020340
# Type_of_collision                0.011909            -0.011049
# Vehicle_movement                 1.000000            -0.004458
# Pedestrian_movement             -0.004458             1.000000
# Cause_of_accident                0.012126             0.002050
# Accident_severity               -0.014015             0.011861
#
#                          Cause_of_accident  Accident_severity
# Age_band_of_driver               -0.005595           0.006573
# Sex_of_driver                     0.001455           0.009192
# Educational_level                 0.002445          -0.001867
# Vehicle_driver_relation          -0.008774           0.000041
# Driving_experience               -0.004232          -0.009876
# Lanes_or_Medians                  0.020810          -0.001877
# Types_of_Junction                -0.003684          -0.008815
# Road_surface_type                -0.022179          -0.003279
# Light_conditions                  0.004206           0.001503
# Weather_conditions                0.000153           0.008444
# Type_of_collision                 0.013962           0.014593
# Vehicle_movement                  0.012126          -0.014015
# Pedestrian_movement               0.002050           0.011861
# Cause_of_accident                 1.000000           0.008886
# Accident_severity                 0.008886           1.000000

# %%
plt.figure(figsize=(15,10))
heatmap=sns.heatmap(d1,linewidth=1,annot=True)

# %% [markdown]
# #### from above heatmap we can conclude that
# #### driving experience and educational level has positive corelation
# #### Driving_experience and Vehicle_driver_relation	has strong positive relaition

# %%
# ageband is no effect on accident_severity
sns.barplot(x="Accident_severity",y="Age_band_of_driver",data=RAS)
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Age_band_of_driver'>

# %%
# from the below graph we can conclude that weather_condition has minimal effect on accident severity
sns.barplot(x="Accident_severity",y="Weather_conditions",data=RAS)
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Weather_conditions'>

# %%
# from below graph we can conclude that weather conditions don't seem to significantly impact the driving experience
sns.barplot(data=RAS,x="Weather_conditions",y="Driving_experience")
# Out:
# <Axes: xlabel='Weather_conditions', ylabel='Driving_experience'>

# %%
#driving experience has effect on accident severity
sns.barplot(x="Accident_severity",y="Driving_experience",data=RAS)
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Driving_experience'>

# %%
#The graph shows that Road_surface_type varies with Accident_severity, and Light_conditions influence this relationship, with noticeable variability especially in conditions 0 and 2
sns.barplot(x="Accident_severity",y="Road_surface_type",hue="Light_conditions",data=RAS)
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Road_surface_type'>

# %%
sns.countplot(x="Accident_severity",data=RAS)
# Target column has Class imbalance issue
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
plt.figure(figsize=[30,10])
sns.boxplot(data=RAS)
# Out:
# <Axes: >

# %% [markdown]
# #### Model Creation

# %%
RAS.head(2)
# Out:
#    Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                   0              1                  0
# 1                   1              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Lanes_or_Medians  \
# 0                        0                   0                 5
# 1                        0                   3                 4
#
#    Types_of_Junction  Road_surface_type  Light_conditions  Weather_conditions  \
# 0                  1                  0                 3                   2
# 1                  1                  0                 3                   2
#
#    Type_of_collision  Vehicle_movement  Pedestrian_movement  \
# 0                  3                 2                    5
# 1                  8                 2                    5
#
#    Cause_of_accident  Accident_severity
# 0                  9                  1
# 1                 16                  1

# %%
RAS.shape
# Out:
# (11768, 15)

# %%
x=RAS.iloc[:,0:-1]
y=RAS.iloc[:,-1]
x.shape,y.shape
# Out:
# ((11768, 14), (11768,))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
x_test.shape,x_train.shape,y_train.shape,y_test.shape
# Out:
# ((2354, 14), (9414, 14), (9414,), (2354,))

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
p=lg.predict(x_test)

# %%
p_value=lg.predict_proba(x_test)

# %%
cm=confusion_matrix(p,y_test)
cm
# Out:
# array([[   0,    0],
#        [ 341, 2013]], dtype=int64)

# %%
ac1=cm.diagonal().sum()/cm.sum()*100
ac1
# Out:
# 85.51401869158879

# %%
TN,FP,FN,TP = cm.ravel()

# %%
lp=TP/(TP+FP)
lp
# Out:
# 1.0

# %%
lr=TP/(TP+FN)
lr
# Out:
# 0.8551401869158879

# %%
lf1=2*(lp*lr)/(lp+lr)
lf1
# Out:
# 0.9219143576826196

# %%
print(classification_report(p,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.86      0.92      2354
#
#     accuracy                           0.86      2354
#    macro avg       0.50      0.43      0.46      2354
# weighted avg       1.00      0.86      0.92      2354

# %%
df=pd.DataFrame(p_value)

# %%
# prc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
precision,recall,threshold=precision_recall_curve(y_test,df.iloc[:,1])

# %%
plt.plot(recall,precision,label="PRC")
plt.xlabel("recall")
plt.ylabel("precision")
plt.legend(loc="upper right")
plt.title("precision-recall")
# Out:
# Text(0.5, 1.0, 'precision-recall')

# %% [markdown]
# #### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
p1=dt.predict(x_test)

# %%
cm1=confusion_matrix(p1,y_test)
cm1
# Out:
# array([[  62,  351],
#        [ 279, 1662]], dtype=int64)

# %%
d_acc=cm1.diagonal().sum()/cm1.sum()*100
d_acc
# Out:
# 73.23704333050128

# %%
print(classification_report(p1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.15      0.16       413
#            1       0.83      0.86      0.84      1941
#
#     accuracy                           0.73      2354
#    macro avg       0.50      0.50      0.50      2354
# weighted avg       0.71      0.73      0.72      2354

# %%
TN1,FP1,FN1,TP1 = cm1.ravel()

# %%
dp= TP1/(TP1+FP1)
dp
# Out:
# 0.8256333830104322

# %%
dr= TP1/(TP1+FN1)
dr
# Out:
# 0.8562596599690881

# %%
df1= 2 * (dp* dr) / (dp + dr)
df1
# Out:
# 0.8406676783004553

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
p2=rf.predict(x_test)

# %%
cm2=confusion_matrix(p2,y_test)
cm2
# Out:
# array([[   3,   33],
#        [ 338, 1980]], dtype=int64)

# %%
rf_ac=cm2.diagonal().sum()/cm2.sum()*100
rf_ac
# Out:
# 84.23959218351742

# %%
TN2,FP2,FN2,TP2 = cm2.ravel()

# %%
rp= TP2/(TP2+FP2)
rp
# Out:
# 0.9836065573770492

# %%
Rr= TP2/(TP2+FN2)
Rr
# Out:
# 0.8541846419327006

# %%
rf1= 2 * (rp* Rr) / (rp + Rr)
rf1
# Out:
# 0.9143384899561302

# %%
print(classification_report(p2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.01      0.08      0.02        36
#            1       0.98      0.85      0.91      2318
#
#     accuracy                           0.84      2354
#    macro avg       0.50      0.47      0.47      2354
# weighted avg       0.97      0.84      0.90      2354

# %% [markdown]
# #### Support vector Machine

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
sp=svc.predict(x_test)

# %%
sm=confusion_matrix(sp,y_test)
sm
# Out:
# array([[   0,    0],
#        [ 341, 2013]], dtype=int64)

# %%
s_acc=sm.diagonal().sum()/sm.sum()*100
s_acc
# Out:
# 85.51401869158879

# %%
print(classification_report(sp,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.86      0.92      2354
#
#     accuracy                           0.86      2354
#    macro avg       0.50      0.43      0.46      2354
# weighted avg       1.00      0.86      0.92      2354

# %%
TN3,FP3,FN3,TP3 = sm.ravel()

# %%
sp= TP3/(TP3+FP3) #precision=tp/tp+fp

# %%
sr=  TP3/(TP3+FN3) #recall=tp/tp+fn
sr
# Out:
# 0.8551401869158879

# %%
sf1= 2 * (sp* sr) / (sp + sr)
sf1
# Out:
# 0.9219143576826196

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()

# %%
nb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
np=nb.predict(x_test)

# %%
nb_m=confusion_matrix(np,y_test)
nb_m
# Out:
# array([[   0,    0],
#        [ 341, 2013]], dtype=int64)

# %%
n_acc=nb_m.diagonal().sum()/nb_m.sum()*100
n_acc
# Out:
# 85.51401869158879

# %%
TN4,FP4,FN4,TP4 = nb_m.ravel()

# %%
np= TP4/(TP4+FP4)
np
# Out:
# 1.0

# %%
nr= TP4/(TP4+FN4)
nr
# Out:
# 0.8551401869158879

# %%
nf1= 2 * (np* nr) / (np + nr)
nf1
# Out:
# 0.9219143576826196

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=40)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
kp=knn.predict(x_test)

# %%
k_c=confusion_matrix(kp,y_test)
k_c
# Out:
# array([[   0,    0],
#        [ 341, 2013]], dtype=int64)

# %%
k_acc=k_c.diagonal().sum()/k_c.sum()*100
k_acc
# Out:
# 85.51401869158879

# %%
TN5,FP5,FN5,TP5 = k_c.ravel()

# %%
kp= TP5/(TP5+FP5)
kp
# Out:
# 1.0

# %%
kr= TP5/(TP5+FN5)
kr
# Out:
# 0.8551401869158879

# %%
kf1= 2 * (kp* kr) / (kp + kr)
kf1
# Out:
# 0.9219143576826196

# %%
# print(classification_report(kp,y_test))

# %% [markdown]
# # Report

# %%
list1=["Logistic","Dt","Rf","Svm","NB","Knn"]
list2=[ac1,d_acc,rf_ac,s_acc,n_acc,k_acc]
# list3=[cm,cm1,cm2,sm,nb_m,k_c]
list4=[lp,dp,rp,sp,np,kp]
list5=[lr,dr,Rr,sr,nr,kr]
list6=[lf1,df1,rf1,sf1,nf1,kf1]

# %%
result=pd.DataFrame({"model_name":list1,"Accuracy":list2,"Precision":list4,"Recall":list5,"F1-Score":list6})
result
# Out:
#   model_name   Accuracy  Precision    Recall  F1-Score
# 0   Logistic  85.514019   1.000000  0.855140  0.921914
# 1         Dt  73.237043   0.825633  0.856260  0.840668
# 2         Rf  84.239592   0.983607  0.854185  0.914338
# 3        Svm  85.514019   1.000000  0.855140  0.921914
# 4         NB  85.514019   1.000000  0.855140  0.921914
# 5        Knn  85.514019   1.000000  0.855140  0.921914

# %% [markdown]
# #### before class-imbalance logistic regression is given me best result

# %% [markdown]
# #### my data has a class imbalance problem so im doing a class imbalance treatment

# %% [markdown]
# # class imbalance

# %% [markdown]
# #### Random over sampling

# %%
RAS.Accident_severity.value_counts()
# Out:
# Accident_severity
# 1    10031
# 0     1737
# Name: count, dtype: int64

# %%
c_1,c_0=RAS["Accident_severity"].value_counts()
c_0,c_1
# Out:
# (1737, 10031)

# %%
train_0=RAS[RAS["Accident_severity"]==0]
train_1=RAS[RAS["Accident_severity"]==1]
train_0.shape,train_1.shape
# Out:
# ((1737, 15), (10031, 15))

# %%
class_1_over=train_0.sample(c_1,replace=True)

# %%
class_1_0=pd.concat([class_1_over,train_1],axis=0)

# %%
class_1_0.shape
# Out:
# (20062, 15)

# %%
class_1_0["Accident_severity"].value_counts()
# Out:
# Accident_severity
# 0    10031
# 1    10031
# Name: count, dtype: int64

# %% [markdown]
# #### Outlier treatment

# %%
sns.boxplot(data=class_1_0,y="Driving_experience")
# Out:
# <Axes: ylabel='Driving_experience'>

# %%
plt.hist(class_1_0["Driving_experience"])
# Out:
# (array([2750., 4327., 5416.,    0., 3678., 2273.,    0.,  190., 1355.,
#           73.]),
#  array([0. , 0.7, 1.4, 2.1, 2.8, 3.5, 4.2, 4.9, 5.6, 6.3, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(class_1_0["Driving_experience"])
# Out:
# <Axes: xlabel='Driving_experience', ylabel='Density'>

# %%
up=class_1_0["Driving_experience"].mean()+3*class_1_0["Driving_experience"].std()
dw=class_1_0["Driving_experience"].mean()-3*class_1_0["Driving_experience"].std()

# %%
class_1_0.loc[class_1_0["Driving_experience"]>up,"Driving_experience"]=up

# %%
sns.distplot(class_1_0["Driving_experience"])
# Out:
# <Axes: xlabel='Driving_experience', ylabel='Density'>

# %%
class_1_0.skew()
# Out:
# Age_band_of_driver         0.843338
# Sex_of_driver             -1.938239
# Educational_level         -0.816279
# Vehicle_driver_relation    1.556892
# Driving_experience         0.702928
# Lanes_or_Medians           0.153195
# Types_of_Junction          0.155119
# Road_surface_type          3.785340
# Light_conditions          -0.993864
# Weather_conditions         2.861019
# Type_of_collision         -1.142935
# Vehicle_movement           2.017278
# Pedestrian_movement       -3.978433
# Cause_of_accident          0.090493
# Accident_severity          0.000000
# dtype: float64

# %%
rx=class_1_0.iloc[:,0:14]
ry=class_1_0.iloc[:,-1]
rx.shape,ry.shape
# Out:
# ((20062, 14), (20062,))

# %%
rx_train,rx_test,ry_train,ry_test=train_test_split(rx,ry,test_size=0.2,random_state=101)

# %%
rx_train.shape,rx_test.shape,ry_train.shape,ry_test.shape
# Out:
# ((16049, 14), (4013, 14), (16049,), (4013,))

# %% [markdown]
# #### Logistic

# %%
lg.fit(rx_train,ry_train)
# Out:
# LogisticRegression()

# %%
pr=lg.predict(rx_test)

# %%
cm11=confusion_matrix(pr,ry_test)
cm11
# Out:
# array([[ 957,  874],
#        [1094, 1088]], dtype=int64)

# %%
ac11=cm11.diagonal().sum()/cm11.sum()*100
ac11
# Out:
# 50.95938200847247

# %%
TN6,FP6,FN6,TP6 = cm11.ravel()

# %%
rolp= TP6/(TP6+FP6)
rolp
# Out:
# 0.5545361875637105

# %%
rolr= TP6/(TP6+FN6)
rolr
# Out:
# 0.4986251145737855

# %%
rolf1= 2 * (rolp*rolr) / (rolp + rolr)
rolf1
# Out:
# 0.5250965250965252

# %%
print(classification_report(pr,ry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.52      0.49      1831
#            1       0.55      0.50      0.53      2182
#
#     accuracy                           0.51      4013
#    macro avg       0.51      0.51      0.51      4013
# weighted avg       0.51      0.51      0.51      4013

# %% [markdown]
# #### Randomforest

# %%
rf.fit(rx_train,ry_train)
# Out:
# RandomForestClassifier()

# %%
rpr=rf.predict(rx_test)

# %%
p_value=rf.predict_proba(rx_test)

# %%
rcm11=confusion_matrix(rpr,ry_test)
rcm11
# Out:
# array([[2029,  146],
#        [  22, 1816]], dtype=int64)

# %%
rac11=rcm11.diagonal().sum()/rcm11.sum()*100
rac11
# Out:
# 95.81360578121107

# %%
TN7,FP7,FN7,TP7 = rcm11.ravel()

# %%
rofp=TP7/(TP7+FP7)
rofp
# Out:
# 0.9255861365953109

# %%
rofr=TP7/(TP7+FN7)
rofr
# Out:
# 0.9880304678998912

# %%
roff1= 2 * (rofp*rofr) / (rofp + rofr)
roff1
# Out:
# 0.9557894736842105

# %%
print(classification_report(rpr,ry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      2175
#            1       0.93      0.99      0.96      1838
#
#     accuracy                           0.96      4013
#    macro avg       0.96      0.96      0.96      4013
# weighted avg       0.96      0.96      0.96      4013

# %%
# Auc curve---TN rate is low
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
roc=roc_auc_score(rpr,ry_test)
roc
# Out:
# 0.960452015559141

# %%
fpr,tpr,threshold=roc_curve(ry_test,rpr)

# %%
plt.plot(fpr,tpr)

# %% [markdown]
# #### Decision Tree

# %%
dt.fit(rx_train,ry_train)
# Out:
# DecisionTreeClassifier()

# %%
dpr=dt.predict(rx_test)

# %%
dcm11=confusion_matrix(dpr,ry_test)
dcm11
# Out:
# array([[2037,  374],
#        [  14, 1588]], dtype=int64)

# %%
dac11=dcm11.diagonal().sum()/dcm11.sum()*100
dac11
# Out:
# 90.33142287565413

# %%
TN8,FP8,FN8,TP8 = dcm11.ravel()

# %%
rodp=TP8/(TP8+FP8)
rodp
# Out:
# 0.8093781855249745

# %%
rodr= TP8/(TP8+FN8)
rodr
# Out:
# 0.9912609238451935

# %%
rodf1= 2 * (rodp*rodr) / (rodp + rodr)
rodf1
# Out:
# 0.8911335578002245

# %%
print(classification_report(dpr,ry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91      2411
#            1       0.81      0.99      0.89      1602
#
#     accuracy                           0.90      4013
#    macro avg       0.90      0.92      0.90      4013
# weighted avg       0.92      0.90      0.90      4013

# %% [markdown]
# #### SVM

# %%
svc.fit(rx_train,ry_train)
# Out:
# SVC()

# %%
spr=svc.predict(rx_test)

# %%
scm11=confusion_matrix(spr,ry_test)
scm11
# Out:
# array([[1309,  919],
#        [ 742, 1043]], dtype=int64)

# %%
sac11=scm11.diagonal().sum()/scm11.sum()*100
sac11
# Out:
# 58.6095190630451

# %%
TN9,FP9,FN9,TP9 = scm11.ravel()

# %%
rosp= TP9/(TP9+FP9)
rosp
# Out:
# 0.5316004077471967

# %%
rosr= TP9/(TP9+FN9)
rosr
# Out:
# 0.5843137254901961

# %%
rosf1= 2 * (rosp*rosr) / (rosp + rosr)
rosf1
# Out:
# 0.5567120362957033

# %%
print(classification_report(spr,ry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.59      0.61      2228
#            1       0.53      0.58      0.56      1785
#
#     accuracy                           0.59      4013
#    macro avg       0.58      0.59      0.58      4013
# weighted avg       0.59      0.59      0.59      4013

# %% [markdown]
# #### NB

# %%
nb.fit(rx_train,ry_train)
# Out:
# MultinomialNB()

# %%
npr=nb.predict(rx_test)

# %%
ncm13=confusion_matrix(npr,ry_test)
ncm13
# Out:
# array([[1000,  929],
#        [1051, 1033]], dtype=int64)

# %%
nac13=ncm13.diagonal().sum()/ncm13.sum()*100
nac13
# Out:
# 50.66035384998754

# %%
TN10,FP10,FN10,TP10= ncm13.ravel()

# %%
nosp= TP10/(TP10+FP10)
nosp
# Out:
# 0.5265035677879715

# %%
nosr= TP10/(TP10+FN10)
nosr
# Out:
# 0.4956813819577735

# %%
nosf1= 2 * (nosp*nosr) / (nosp + nosr)
nosf1
# Out:
# 0.5106277805239743

# %%
print(classification_report(npr,ry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.52      0.50      1929
#            1       0.53      0.50      0.51      2084
#
#     accuracy                           0.51      4013
#    macro avg       0.51      0.51      0.51      4013
# weighted avg       0.51      0.51      0.51      4013

# %% [markdown]
# #### KNN

# %%
knn.fit(rx_train,ry_train)
# Out:
# KNeighborsClassifier(n_neighbors=40)

# %%
knpr=knn.predict(rx_test)

# %%
kncm14=confusion_matrix(knpr,ry_test)
kncm14
# Out:
# array([[1432, 1051],
#        [ 619,  911]], dtype=int64)

# %%
knac11=kncm14.diagonal().sum()/kncm14.sum()*100
knac11
# Out:
# 58.38524794418141

# %%
TN11,FP11,FN11,TP11 = kncm14.ravel()

# %%
knosp= TP11/(TP11+FP11)
knosp
# Out:
# 0.464322120285423

# %%
knosr=  TP11/(TP11+FN11)
knosr
# Out:
# 0.5954248366013072

# %%
knosf1= 2 * (knosp*knosr) / (knosp + knosr)
knosf1
# Out:
# 0.5217640320733105

# %%
print(classification_report(knpr,ry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.63      2483
#            1       0.46      0.60      0.52      1530
#
#     accuracy                           0.58      4013
#    macro avg       0.58      0.59      0.58      4013
# weighted avg       0.61      0.58      0.59      4013

# %% [markdown]
# # class-imbalance-Random-report

# %%
l1=["Logistic","RF","Dt","SVC","NB","KN"]
l2=[ac11,rac11,dac11,sac11,nac13,knac11]
l4=[rolp,rofp,rodp,rosp,nosp,knosp]
l5=[rolr,rofr,rodr,rosr,nosr,knosr]
l6=[rolf1,roff1,rodf1,rosf1,nosf1,knosf1]

# %%
result1=pd.DataFrame({"model_name":l1,"Accuracy":l2,"Precision":l4,"Recall":l5,"F1-Score":l6})
result1
# Out:
#   model_name   Accuracy  Precision    Recall  F1-Score
# 0   Logistic  50.959382   0.554536  0.498625  0.525097
# 1         RF  95.813606   0.925586  0.988030  0.955789
# 2         Dt  90.331423   0.809378  0.991261  0.891134
# 3        SVC  58.609519   0.531600  0.584314  0.556712
# 4         NB  50.660354   0.526504  0.495681  0.510628
# 5         KN  58.385248   0.464322  0.595425  0.521764

# %% [markdown]
# #### i have applied all the over sampling techniques from that random over sampling is given me better result for RandomForest.

# %% [markdown]
# # feature selection

# %% [markdown]
# #### RFS

# %%
rfe=RFE(dt)

# %%
rfe.fit(rx,ry)
# Out:
# RFE(estimator=DecisionTreeClassifier())

# %%
rfe.support_
# Out:
# array([ True, False,  True, False,  True,  True, False, False, False,
#        False,  True,  True, False,  True])

# %%
df3=pd.DataFrame(rfe.support_)
df3
# Out:
#         0
# 0    True
# 1   False
# 2    True
# 3   False
# 4    True
# 5    True
# 6   False
# 7   False
# 8   False
# 9   False
# 10   True
# 11   True
# 12  False
# 13   True

# %%
pdf4=pd.DataFrame({"feature_score":list(rfe.support_),"columns":list(class_1_0.iloc[:,:-1])})
pdf4
# Out:
#     feature_score                  columns
# 0            True       Age_band_of_driver
# 1           False            Sex_of_driver
# 2            True        Educational_level
# 3           False  Vehicle_driver_relation
# 4            True       Driving_experience
# 5            True         Lanes_or_Medians
# 6           False        Types_of_Junction
# 7           False        Road_surface_type
# 8           False         Light_conditions
# 9           False       Weather_conditions
# 10           True        Type_of_collision
# 11           True         Vehicle_movement
# 12          False      Pedestrian_movement
# 13           True        Cause_of_accident

# %%
data_newx=class_1_0.drop(["Age_band_of_driver","Sex_of_driver","Types_of_Junction","Road_surface_type","Light_conditions","Weather_conditions","Pedestrian_movement"],axis=1)
data_newx
# Out:
#        Educational_level  Vehicle_driver_relation  Driving_experience  \
# 81                     4                        0                 0.0
# 9197                   4                        0                 2.0
# 9639                   1                        0                 2.0
# 837                    4                        2                 6.0
# 6639                   4                        0                 4.0
# ...                  ...                      ...                 ...
# 12151                  1                        0                 2.0
# 12153                  5                        0                 1.0
# 12154                  1                        0                 2.0
# 12156                  4                        0                 3.0
# 12157                  4                        0                 2.0
#
#        Lanes_or_Medians  Type_of_collision  Vehicle_movement  \
# 81                    0                  2                 2
# 9197                  1                  8                 9
# 9639                  2                  8                 2
# 837                   4                  8                 2
# 6639                  4                  8                 4
# ...                 ...                ...               ...
# 12151                 6                  2                 2
# 12153                 4                  8                 2
# 12154                 2                  8                 4
# 12156                 4                  8                 4
# 12157                 4                  8                 8
#
#        Cause_of_accident  Accident_severity
# 81                    17                  0
# 9197                  10                  0
# 9639                   3                  0
# 837                   16                  0
# 6639                   0                  0
# ...                  ...                ...
# 12151                  4                  1
# 12153                 10                  1
# 12154                 10                  1
# 12156                  5                  1
# 12157                  1                  1
#
# [20062 rows x 8 columns]

# %%
xrf=data_newx.iloc[:,0:-1]
yrf=data_newx.iloc[:,-1]

# %%
xrf.shape,yrf.shape
# Out:
# ((20062, 7), (20062,))

# %%
frx_train,frx_test,fry_train,fry_test=train_test_split(xrf,yrf,test_size=0.2,random_state=101)

# %%
frx_train.shape,frx_test.shape,fry_train.shape,fry_test.shape
# Out:
# ((16049, 7), (4013, 7), (16049,), (4013,))

# %%
rf.fit(frx_train,fry_train)
# Out:
# RandomForestClassifier()

# %%
fpr1=rf.predict(frx_test)

# %%
frcm11=confusion_matrix(fpr1,fry_test)
frcm11
# Out:
# array([[1817,  495],
#        [ 234, 1467]], dtype=int64)

# %%
frac11=frcm11.diagonal().sum()/frcm11.sum()*100
frac11
# Out:
# 81.83403937204086

# %%
TNf,FPf,FNf,TPf = frcm11.ravel()

# %%
frofp=TPf/(TPf+FPf)
frofp
# Out:
# 0.7477064220183486

# %%
frofr=TPf/(TPf+FNf)
frofr
# Out:
# 0.8624338624338624

# %%
froff1= 2 * (frofp*frofr) / (frofp + frofr)
froff1
# Out:
# 0.800982800982801

# %%
print(classification_report(fpr1,fry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.79      0.83      2312
#            1       0.75      0.86      0.80      1701
#
#     accuracy                           0.82      4013
#    macro avg       0.82      0.82      0.82      4013
# weighted avg       0.83      0.82      0.82      4013

# %% [markdown]
# #### chisquare

# %%
cst=SelectKBest(score_func=chi2,k="all")

# %%
cst_fit=cst.fit(rx,ry)
cst_fit
# Out:
# SelectKBest(k='all', score_func=<function chi2 at 0x0000021D33150360>)

# %%
cst_score=cst_fit.scores_
cst_score
# Out:
# array([9.87640796e+00, 1.94338539e-01, 3.38570005e-02, 7.53332644e-02,
#        2.76103039e+00, 4.10394471e-04, 4.47680228e+00, 2.40939865e+00,
#        1.58692497e-01, 1.37092722e+00, 1.41214915e+01, 1.32736822e+01,
#        3.96785722e-01, 1.47563789e+01])

# %%
rdf2=pd.DataFrame(cst_score)
rdf2
# Out:
#             0
# 0    9.876408
# 1    0.194339
# 2    0.033857
# 3    0.075333
# 4    2.761030
# 5    0.000410
# 6    4.476802
# 7    2.409399
# 8    0.158692
# 9    1.370927
# 10  14.121491
# 11  13.273682
# 12   0.396786
# 13  14.756379

# %%
rpdf3=pd.DataFrame({"feature_score":list(cst_score),"columns":list(class_1_0.iloc[:,:-1])})
rpdf3
# Out:
#     feature_score                  columns
# 0        9.876408       Age_band_of_driver
# 1        0.194339            Sex_of_driver
# 2        0.033857        Educational_level
# 3        0.075333  Vehicle_driver_relation
# 4        2.761030       Driving_experience
# 5        0.000410         Lanes_or_Medians
# 6        4.476802        Types_of_Junction
# 7        2.409399        Road_surface_type
# 8        0.158692         Light_conditions
# 9        1.370927       Weather_conditions
# 10      14.121491        Type_of_collision
# 11      13.273682         Vehicle_movement
# 12       0.396786      Pedestrian_movement
# 13      14.756379        Cause_of_accident

# %%
dnewx=class_1_0.drop(["Age_band_of_driver","Sex_of_driver","Educational_level","Vehicle_driver_relation","Lanes_or_Medians","Light_conditions","Weather_conditions","Pedestrian_movement"],axis=1)
dnewx
# Out:
#        Driving_experience  Types_of_Junction  Road_surface_type  \
# 81                    0.0                  0                  0
# 9197                  2.0                  0                  5
# 9639                  2.0                  1                  0
# 837                   6.0                  3                  0
# 6639                  4.0                  1                  0
# ...                   ...                ...                ...
# 12151                 2.0                  1                  0
# 12153                 1.0                  1                  0
# 12154                 2.0                  1                  0
# 12156                 3.0                  1                  0
# 12157                 2.0                  2                  0
#
#        Type_of_collision  Vehicle_movement  Cause_of_accident  \
# 81                     2                 2                 17
# 9197                   8                 9                 10
# 9639                   8                 2                  3
# 837                    8                 2                 16
# 6639                   8                 4                  0
# ...                  ...               ...                ...
# 12151                  2                 2                  4
# 12153                  8                 2                 10
# 12154                  8                 4                 10
# 12156                  8                 4                  5
# 12157                  8                 8                  1
#
#        Accident_severity
# 81                     0
# 9197                   0
# 9639                   0
# 837                    0
# 6639                   0
# ...                  ...
# 12151                  1
# 12153                  1
# 12154                  1
# 12156                  1
# 12157                  1
#
# [20062 rows x 7 columns]

# %%
cxrf=dnewx.iloc[:,0:-1]
cyrf=dnewx.iloc[:,-1]

# %%
cxrf.shape,cyrf.shape
# Out:
# ((20062, 6), (20062,))

# %%
cfrx_train,cfrx_test,cfry_train,cfry_test=train_test_split(cxrf,cyrf,test_size=0.2,random_state=101)

# %%
cfrx_train.shape,cfrx_test.shape,cfry_train.shape,cfry_test.shape
# Out:
# ((16049, 6), (4013, 6), (16049,), (4013,))

# %%
rf.fit(cfrx_train,cfry_train)
# Out:
# RandomForestClassifier()

# %%
cfpr1=rf.predict(cfrx_test)

# %%
cfrcm11=confusion_matrix(cfpr1,cfry_test)
cfrcm11
# Out:
# array([[1676,  619],
#        [ 375, 1343]], dtype=int64)

# %%
cfrac11=cfrcm11.diagonal().sum()/cfrcm11.sum()*100
cfrac11
# Out:
# 75.23050087216546

# %%
TNcf,FPcf,FNcf,TPcf = cfrcm11.ravel()

# %%
cfrofp=TPcf/(TPcf+FPcf)
cfrofp
# Out:
# 0.6845056065239552

# %%
cfrofr=TPcf/(TPcf+FNcf)
cfrofr
# Out:
# 0.7817229336437719

# %%
cfroff1= 2 * (cfrofp*cfrofr) / (cfrofp + cfrofr)
cfroff1
# Out:
# 0.7298913043478261

# %%
print(classification_report(cfpr1,cfry_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77      2295
#            1       0.68      0.78      0.73      1718
#
#     accuracy                           0.75      4013
#    macro avg       0.75      0.76      0.75      4013
# weighted avg       0.76      0.75      0.75      4013

# %% [markdown]
# #### Feature Report

# %%
fl1=["RF-RFE","RF-chi"]
fl2=[frac11,cfrac11]
fl4=[frofp,cfrofp]
fl5=[frofr,cfrofr]
fl6=[froff1,cfroff1]

# %%
fresult1=pd.DataFrame({"model_name":fl1,"Accuracy":fl2,"Precision":fl4,"Recall":fl5,"F1-Score":fl6})
fresult1
# Out:
#   model_name   Accuracy  Precision    Recall  F1-Score
# 0     RF-RFE  81.834039   0.747706  0.862434  0.800983
# 1     RF-chi  75.230501   0.684506  0.781723  0.729891

# %% [markdown]
# #### Feature selection is not sutaible for this data beacause it is reducing the accuracy

# %% [markdown]
# # Model validation

# %% [markdown]
# #### cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(rf, rx, ry, cv=5)

# %%
print(f"Cross-validation scores: {scores}")
print(f"Mean CV accuracy: {scores.mean():.2f}")
# Out:
# Cross-validation scores: [0.94866683 0.96361824 0.94915254 0.95737787 0.88185444]
# Mean CV accuracy: 0.94

# %% [markdown]
# #### StratifiedKFold

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=5)

# %%
scores2 = cross_val_score(rf, rx, ry, cv=skf)

# %%
print(f"Stratified CV accuracy: {scores2.mean():.2f}")
# Out:
# Stratified CV accuracy: 0.94

# %% [markdown]
# #### both Cross validation and Stratified K-Fold validation techniques yielded a validation score of 0.94,
# #### indicating consistent performance across different validation methods.
# #### This suggests that the model is robust and performs well regardless of the validation approach used.
